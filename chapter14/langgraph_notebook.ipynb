# %% [markdown]
# # LangGraph Agent
# ## Without tools

# %% [markdown]
# ## Library imports

# %%
from langchain_core.messages import HumanMessage
from langchain_anthropic import ChatAnthropic
from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import END, START, StateGraph, MessagesState
import logging
from IPython.display import Image, Markdown, display
from langchain_core.runnables.graph import CurveStyle, MermaidDrawMethod, NodeStyles

# %% [markdown]
# ## Configure logging

# %%
for handler in logging.root.handlers[:]:
    logging.root.removeFilter(handler)

logging.basicConfig(
    filename='langgraph_notebook.log',
    level=logging.INFO
)

# %% [markdown]
# ## Configure Agent and Model

# %%
model = ChatAnthropic(model='claude-3-5-sonnet-20240620', temperature=0)

def call_model(state: MessagesState):
    messages = state['messages']
    response = model.invoke(messages)
    return {"messages": [response]}

workflow = StateGraph(MessagesState)

workflow.add_node("agent", call_model)

workflow.add_edge(START, "agent")

checkpointer = MemorySaver()

app = workflow.compile(checkpointer=checkpointer)

# %% [markdown]
# ## Visualize the graph

# %%
display(
    Image(
        app.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %% [markdown]
# ## Chat with the Agent

# %%
final_state = app.invoke(
    {"messages": [HumanMessage(content="What teams did Joe Montana play for?")]},
    config={"configurable": {"thread_id": 99}}
)
display(Markdown(final_state["messages"][-1].content))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 final_state = app.invoke(
#       2     {"messages": [HumanMessage(content="What teams did Joe Montana play for?")]},
#       3     config={"configurable": {"thread_id": 99}}
#       4 )
#       5 display(Markdown(final_state["messages"][-1].content))
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/langgraph/pregel/__init__.py:2336, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    2334 else:
#    2335     chunks = []
# -> 2336 for chunk in self.stream(
#    2337     input,
#    2338     config,
#    2339     stream_mode=stream_mode,
#    2340     output_keys=output_keys,
#    2341     interrupt_before=interrupt_before,
#    2342     interrupt_after=interrupt_after,
#    2343     debug=debug,
#    2344     **kwargs,
#    2345 ):
#    2346     if stream_mode == "values":
#    2347         latest = chunk
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/langgraph/pregel/__init__.py:1993, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1987     # Similarly to Bulk Synchronous Parallel / Pregel model
#    1988     # computation proceeds in steps, while there are channel updates.
#    1989     # Channel updates from step N are only visible in step N+1
#    1990     # channels are guaranteed to be immutable for the duration of the step,
#    1991     # with channel updates applied only at the transition between steps.
#    1992     while loop.tick(input_keys=self.input_channels):
# -> 1993         for _ in runner.tick(
#    1994             loop.tasks.values(),
#    1995             timeout=self.step_timeout,
#    1996             retry_policy=self.retry_policy,
#    1997             get_waiter=get_waiter,
#    1998         ):
#    1999             # emit output
#    2000             yield from output()
#    2001 # emit output
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/langgraph/pregel/runner.py:230, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     228 t = tasks[0]
#     229 try:
# --> 230     run_with_retry(
#     231         t,
#     232         retry_policy,
#     233         configurable={
#     234             CONFIG_KEY_SEND: partial(writer, t),
#     235             CONFIG_KEY_CALL: partial(call, t),
#     236         },
#     237     )
#     238     self.commit(t, None)
#     239 except Exception as exc:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/langgraph/pregel/retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/langgraph/utils/runnable.py:546, in RunnableSeq.invoke(self, input, config, **kwargs)
#     542 config = patch_config(
#     543     config, callbacks=run_manager.get_child(f"seq:step:{i + 1}")
#     544 )
#     545 if i == 0:
# --> 546     input = step.invoke(input, config, **kwargs)
#     547 else:
#     548     input = step.invoke(input, config)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/langgraph/utils/runnable.py:310, in RunnableCallable.invoke(self, input, config, **kwargs)
#     308 else:
#     309     context.run(_set_config_context, config)
# --> 310     ret = context.run(self.func, *args, **kwargs)
#     311 if isinstance(ret, Runnable) and self.recurse:
#     312     return ret.invoke(input, config)
#
# Cell In[3], line 5, in call_model(state)
#       3 def call_model(state: MessagesState):
#       4     messages = state['messages']
# ----> 5     response = model.invoke(messages)
#       6     return {"messages": [response]}
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:370, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     358 @override
#     359 def invoke(
#     360     self,
#    (...)    365     **kwargs: Any,
#     366 ) -> BaseMessage:
#     367     config = ensure_config(config)
#     368     return cast(
#     369         "ChatGeneration",
# --> 370         self.generate_prompt(
#     371             [self._convert_input(input)],
#     372             stop=stop,
#     373             callbacks=config.get("callbacks"),
#     374             tags=config.get("tags"),
#     375             metadata=config.get("metadata"),
#     376             run_name=config.get("run_name"),
#     377             run_id=config.pop("run_id", None),
#     378             **kwargs,
#     379         ).generations[0][0],
#     380     ).message
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:947, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     938 @override
#     939 def generate_prompt(
#     940     self,
#    (...)    944     **kwargs: Any,
#     945 ) -> LLMResult:
#     946     prompt_messages = [p.to_messages() for p in prompts]
# --> 947     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:766, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     763 for i, m in enumerate(input_messages):
#     764     try:
#     765         results.append(
# --> 766             self._generate_with_cache(
#     767                 m,
#     768                 stop=stop,
#     769                 run_manager=run_managers[i] if run_managers else None,
#     770                 **kwargs,
#     771             )
#     772         )
#     773     except BaseException as e:
#     774         if run_managers:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1012, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1010     result = generate_from_stream(iter(chunks))
#    1011 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1012     result = self._generate(
#    1013         messages, stop=stop, run_manager=run_manager, **kwargs
#    1014     )
#    1015 else:
#    1016     result = self._generate(messages, stop=stop, **kwargs)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/langchain_anthropic/chat_models.py:796, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#     794     return generate_from_stream(stream_iter)
#     795 payload = self._get_request_payload(messages, stop=stop, **kwargs)
# --> 796 data = self._client.messages.create(**payload)
#     797 return self._format_output(data, **kwargs)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/anthropic/_utils/_utils.py:283, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     281             msg = f"Missing required argument: {quote(missing[0])}"
#     282     raise TypeError(msg)
# --> 283 return func(*args, **kwargs)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/anthropic/resources/messages/messages.py:954, in Messages.create(self, max_tokens, messages, model, metadata, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     947 if model in DEPRECATED_MODELS:
#     948     warnings.warn(
#     949         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     950         DeprecationWarning,
#     951         stacklevel=3,
#     952     )
# --> 954 return self._post(
#     955     "/v1/messages",
#     956     body=maybe_transform(
#     957         {
#     958             "max_tokens": max_tokens,
#     959             "messages": messages,
#     960             "model": model,
#     961             "metadata": metadata,
#     962             "stop_sequences": stop_sequences,
#     963             "stream": stream,
#     964             "system": system,
#     965             "temperature": temperature,
#     966             "thinking": thinking,
#     967             "tool_choice": tool_choice,
#     968             "tools": tools,
#     969             "top_k": top_k,
#     970             "top_p": top_p,
#     971         },
#     972         message_create_params.MessageCreateParamsStreaming
#     973         if stream
#     974         else message_create_params.MessageCreateParamsNonStreaming,
#     975     ),
#     976     options=make_request_options(
#     977         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     978     ),
#     979     cast_to=Message,
#     980     stream=stream or False,
#     981     stream_cls=Stream[RawMessageStreamEvent],
#     982 )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/anthropic/_base_client.py:1290, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1276 def post(
#    1277     self,
#    1278     path: str,
#    (...)   1285     stream_cls: type[_StreamT] | None = None,
#    1286 ) -> ResponseT | _StreamT:
#    1287     opts = FinalRequestOptions.construct(
#    1288         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1289     )
# -> 1290     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/anthropic/_base_client.py:1009, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1006 options = self._prepare_options(options)
#    1008 remaining_retries = max_retries - retries_taken
# -> 1009 request = self._build_request(options, retries_taken=retries_taken)
#    1010 self._prepare_request(request)
#    1012 kwargs: HttpxSendArgs = {}
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/anthropic/_base_client.py:505, in BaseClient._build_request(self, options, retries_taken)
#     502     else:
#     503         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 505 headers = self._build_headers(options, retries_taken=retries_taken)
#     506 params = _merge_mappings(self.default_query, options.params)
#     507 content_type = headers.get("Content-Type")
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/anthropic/_base_client.py:446, in BaseClient._build_headers(self, options, retries_taken)
#     436 custom_headers = options.headers or {}
#     437 headers_dict = _merge_mappings(
#     438     {
#     439         "x-stainless-timeout": str(options.timeout.read)
#    (...)    444     custom_headers,
#     445 )
# --> 446 self._validate_headers(headers_dict, custom_headers)
#     448 # headers are case-insensitive while dictionaries are not.
#     449 headers = httpx.Headers(headers_dict)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/anthropic/_client.py:196, in Anthropic._validate_headers(self, headers, custom_headers)
#     193 if isinstance(custom_headers.get("Authorization"), Omit):
#     194     return
# --> 196 raise TypeError(
#     197     '"Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     198 )
#
# TypeError: "Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"
# During task with name 'agent' and id '10b7fdae-cd6c-669a-56bb-8348d5a50acd'
